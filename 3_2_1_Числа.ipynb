# %% [markdown]
# <a href="https://colab.research.google.com/github/BosenkoTM/OOAP2/blob/main/3_2_1_%D0%A7%D0%B8%D1%81%D0%BB%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **№ 3.2.1**
#
# Составьте программу, которая запрашивает у пользователя 2 целых числа и выполняет операции:
#
# арифметические: +, -, * , / , // , %, **;
#
# сравнение: <, <=, >, >=, !=, ==,
#
# выводя на экран результат каждого действия. В случае получение вещественного результата, округлите его до 2-х знаков после запятой (используя функцию round()).

# %%
# Программирование на языке высокого уровня (Python).
# https://www.yuripetrov.ru/edu/python
# Задание task_03_02_01.
#
# Выполнил: Фамилия И.О.
# Группа: !!!



a = int(input("a="))
b = int(input("b="))

print(a + b)
print(a - b)
print(a * b)
print(round(a / b,2))
print(a // b)
print(a % b)
print(a ** b)



print(a < b)



# --------------
# Пример вывода:
#
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True
# True
# False
# False
# True
# False
# Out:
# a=2
# b=3
# 5
# -1
# 6
# 0.67
# 0
# 2
# 8
# True

# %% [markdown]
# № 3.2.2
#
# Вычислите значение следующего выражения (аргументы - целые числа и вводятся с клавиатуры):
#
# ![1.JPG](data:image/jpeg;base64,...)
#
#
# Округлите результат до 3-х знаков после запятой, используя функцию round().

# %%
import math
x =0 # Удалите комментарий и допишите код
y =1 # Удалите комментарий и допишите код
z =2 # Удалите комментарий и допишите код

res1 = ((x**5+7)/(abs(-6)*y))**(1/3)# Удалите комментарий и допишите код
res2=7- (z % y)
res=res1/res2
print(round(res,2))
# Out:
# 0.15
